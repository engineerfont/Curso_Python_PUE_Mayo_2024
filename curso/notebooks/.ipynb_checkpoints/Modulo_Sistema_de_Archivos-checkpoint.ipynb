# %% [markdown]
# ### Módulo **os** para el manejo del sistema de archivos del sistema operativo

# %% [markdown]
# Importamos el módulo **os** de Python

# %%
import os

# %% [markdown]
# Importamos el módulo ***sys*** de Python

# %%
import sys

# %% [markdown]
# Indicamos la ruta en donde buscar los módulos de la aplicación

# %%
sys.path.append('../')

# %% [markdown]
# ### Principales funciones y propiedades del módulo **os**

# %% [markdown]
# La propiedad os.**name** muestra el tipo de sistema operativo

# %%
os.name
# Out:
# 'nt'

# %% [markdown]
# #### Funciones para trabajar con directorios

# %% [markdown]
# La función os.**mkdir**, crea un directorio y lanza una excepción si ya existe el directorio.

# %%
os.mkdir('nuevo_dir')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 os.mkdir('nuevo_dir')
#
# FileExistsError: [WinError 183] No se puede crear un archivo que ya existe: 'nuevo_dir'

# %% [markdown]
# Ejemplo de una función que crea un directorio.

# %%
def dir(directorio):
    try:
        os.mkdir(directorio)
    except FileExistsError as fee:
        print('El directorio ya existe')

dir('nuevo_dir/uno/dos')

# %% [markdown]
# La función os.**makedirs**, crea directorios y lanza una excepción si ya existen los directorios.

# %%
os.makedirs('nuevo_dir/uno/dos')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 os.makedirs('nuevo_dir/uno/dos')
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] No se puede crear un archivo que ya existe: 'nuevo_dir/uno/dos'

# %% [markdown]
# Ejemplo de una función que crea directorios.

# %%
def dirs(directorios):
    try:
        os.makedirs(directorios)
    except FileExistsError as fee:
        print('El directorio ya existe')

dirs('nuevo_dir/uno/dos')

# %% [markdown]
# Si cuando utilizamos la función os.**makedirs** indicamos su parámetro *exist_ok* igual a **True**, no se lanzará ninguna excepción, independientemente de que ya existan los directorios.

# %%
os.makedirs('nuevo_dir/uno/dos', exist_ok=True)

# %% [markdown]
# La función os.**chdir**, cambia de un directorio a otro directorio, lanza una excepción si no encuentra el directorio.

# %%
os.chdir('/dis/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 os.chdir('/dis/')
#
# FileNotFoundError: [WinError 2] El sistema no puede encontrar el archivo especificado: '/dis/'

# %% [markdown]
# Ejemplo de una función que cambia de directorio.

# %%
def cd(directorio):
    try:
        os.chdir(directorio)
    except FileNotFoundError as fnfe:
        print('El directorio no existe')

cd('../../')

# %% [markdown]
# La función os.**rmdir**, elimina un directorio, lanza una excepción si el directorio no existe o el directorio no está vacío.

# %%
os.rmdir('nuevo_dir/uno/dos')

# %% [markdown]
# Ejemplo de una función que elimina un directorio.

# %%
def rm(directorio):
    try:
        os.rmdir(directorio)
    except FileNotFoundError as fnfe:
        print('El directorio no existe')
    except OSError as oe:
        print('El directorio no está vacío')

rm('nuevo_dir/uno/dos')
# Out:
# El directorio no existe

# %% [markdown]
# La función os.**removedirs**, elimina directorios, lanza una excepción si los directorios no existen o están vacíos.

# %%
os.removedirs('nuevo_dir/uno')

# %% [markdown]
# Ejemplo de una función que elimina directorios.

# %%
def rmdirs(directorios):
    try:
        os.removedirs(directorios)
    except FileNotFoundError as fnfe:
        print('Los directorios no existen')
    except OSError as oe:
        print('Los directorios no están vacíos')

rmdirs('nuevo_dir/uno')
# Out:
# Los directorios no existen

# %% [markdown]
# La función os.**getcwd**, muestra la ruta actual del directorio de trabajo.

# %%
os.getcwd()
# Out:
# 'C:\\Proyectos\\idea\\python\\CursoPythonPueMayo\\curso\\notebooks'

# %% [markdown]
# La función os.**system**, ejecuta un comando del sistema operativo.

# %%
os.system('mkdir novo')
# Out:
# 0

# %% [markdown]
# #### Funciones para obtener información sobre los directorios y archivos del sistema.

# %% [markdown]
# La función os.**listdir**, devuelve una lista con el contenido (subdirectorios y archivos) de un directorio.

# %%
contenido = os.listdir('c:\\datasets')
contenido
# Out:
# ['csv',
#  'data',
#  'databricks',
#  'datos',
#  'datos_v2.1',
#  'dni',
#  'excel',
#  'general',
#  'imagenes',
#  'libros',
#  'mail',
#  'malware',
#  'seguridad',
#  'sites',
#  'tool4mob',
#  'tool4mob_v2.1',
#  'tool4mov_database_v2.1']

# %% [markdown]
# La función os.**scandir**, devuelve las entradas (subdirectorios y archivos) del contenido de un directorio.

# %%
directorio = 'c:\\datasets'
try:
    with os.scandir(directorio) as entries:
        for entry in entries:
            print(entry.stat())
except FileNotFoundError as fnfe:
    print('El directorio no existe')
# Out:
# os.stat_result(st_mode=16895, st_ino=0, st_dev=0, st_nlink=0, st_uid=0, st_gid=0, st_size=0, st_atime=1715632862, st_mtime=1695722763, st_ctime=0)
# os.stat_result(st_mode=16895, st_ino=0, st_dev=0, st_nlink=0, st_uid=0, st_gid=0, st_size=0, st_atime=1715632862, st_mtime=1714667856, st_ctime=0)
# os.stat_result(st_mode=16895, st_ino=0, st_dev=0, st_nlink=0, st_uid=0, st_gid=0, st_size=0, st_atime=1716285437, st_mtime=1700559798, st_ctime=0)
# os.stat_result(st_mode=16895, st_ino=0, st_dev=0, st_nlink=0, st_uid=0, st_gid=0, st_size=0, st_atime=1715632862, st_mtime=1714405126, st_ctime=0)
# os.stat_result(st_mode=16895, st_ino=0, st_dev=0, st_nlink=0, st_uid=0, st_gid=0, st_size=0, st_atime=1715632862, st_mtime=1704731595, st_ctime=0)
# os.stat_result(st_mode=16895, st_ino=0, st_dev=0, st_nlink=0, st_uid=0, st_gid=0, st_size=0, st_atime=1715632862, st_mtime=1710436855, st_ctime=0)
# os.stat_result(st_mode=16895, st_ino=0, st_dev=0, st_nlink=0, st_uid=0, st_gid=0, st_size=0, st_atime=1715632862, st_mtime=1702553169, st_ctime=0)
# os.stat_result(st_mode=16895, st_ino=0, st_dev=0, st_nlink=0, st_uid=0, st_gid=0, st_size=0, st_atime=1715632862, st_mtime=1684679536, st_ctime=0)
# os.stat_result(st_mode=16895, st_ino=0, st_dev=0, st_nlink=0, st_uid=0, st_gid=0, st_size=0, st_atime=1715632862, st_mtime=1699963399, st_ctime=0)
# os.stat_result(st_mode=16895, st_ino=0, st_dev=0, st_nlink=0, st_uid=0, st_gid=0, st_size=0, st_atime=1715632862, st_mtime=1684679589, st_ctime=0)
# os.stat_result(st_mode=16895, st_ino=0, st_dev=0, st_nlink=0, st_uid=0, st_gid=0, st_size=0, st_atime=1715632862, st_mtime=1702252759, st_ctime=0)
# os.stat_result(st_mode=16895, st_ino=0, st_dev=0, st_nlink=0, st_uid=0, st_gid=0, st_size=0, st_atime=1715632862, st_mtime=1702557787, st_ctime=0)
# os.stat_result(st_mode=16895, st_ino=0, st_dev=0, st_nlink=0, st_uid=0, st_gid=0, st_size=0, st_atime=1715632862, st_mtime=1708297086, st_ctime=0)
# os.stat_result(st_mode=16895, st_ino=0, st_dev=0, st_nlink=0, st_uid=0, st_gid=0, st_size=0, st_atime=1715632862, st_mtime=1714390902, st_ctime=0)
# os.stat_result(st_mode=16895, st_ino=0, st_dev=0, st_nlink=0, st_uid=0, st_gid=0, st_size=0, st_atime=1715632862, st_mtime=1707936611, st_ctime=0)
# os.stat_result(st_mode=16895, st_ino=0, st_dev=0, st_nlink=0, st_uid=0, st_gid=0, st_size=0, st_atime=1715632862, st_mtime=1704731640, st_ctime=0)
# os.stat_result(st_mode=16895, st_ino=0, st_dev=0, st_nlink=0, st_uid=0, st_gid=0, st_size=0, st_atime=1715632862, st_mtime=1704800178, st_ctime=0)

# %% [markdown]
# La función os.**walk**, obtiene toda la información (subdirectorios y archivos) del directorio y de sus subdirectorios

# %%
directorio = 'c:\\datasets'
for (dir, subdir, files) in os.walk(directorio):
    for file in files:
        print(os.path.join(dir, file))
# Out:
# c:\datasets\csv\accidentalidad_2008.csv
# c:\datasets\csv\BERT_sentiment_IMDB_Dataset.csv
# c:\datasets\csv\empresas.csv
# c:\datasets\csv\empresas_seguridad.csv
# c:\datasets\csv\housing.csv
# c:\datasets\csv\housing.data
# c:\datasets\csv\jena_climate_2009_2016.csv
# c:\datasets\csv\taxi_flota_diario.csv
# c:\datasets\data\apellidos.data
# c:\datasets\data\c1.txt
# c:\datasets\data\ccaa.data
# c:\datasets\data\codes.md
# c:\datasets\data\direcciones.data
# c:\datasets\data\filesystem.data
# c:\datasets\data\filesystem.json
# c:\datasets\data\housing.csv
# c:\datasets\data\housing.data
# c:\datasets\data\housing.data.save
# c:\datasets\data\logo.png
# c:\datasets\data\municipios.data
# c:\datasets\data\nombres.data
# c:\datasets\data\nomes.pdf
# c:\datasets\data\nomes_catalans.pdf
# c:\datasets\data\nomes_catalans.txt
# c:\datasets\data\personas.dat
# c:\datasets\data\poblaciones.data
# c:\datasets\data\poblaciones.json
# c:\datasets\data\provincias.csv
# c:\datasets\data\provincias.data
# c:\datasets\data\usuarios.data
# c:\datasets\databricks\datos\streaming.zip
# c:\datasets\databricks\datos\book\Data Engineering with Apache Spark, Delta Lake, and Lakehouse.pdf
# c:\datasets\databricks\datos\csv\accidentalidad_2008.csv
# c:\datasets\databricks\datos\csv\empresas.csv
# c:\datasets\databricks\datos\csv\empresas_seguridad.csv
# c:\datasets\databricks\datos\csv\housing.csv
# c:\datasets\databricks\datos\csv\housing2.data
# c:\datasets\databricks\datos\csv\provincias.data
# c:\datasets\databricks\datos\csv\taxi_flota_diario.csv
# c:\datasets\databricks\datos\notebooks\Ejemplo 1. Leer fichero y crear tablas y archivos.ipynb
# c:\datasets\databricks\datos\notebooks\Ejemplo 2. Cambiar nombres de columna y funciones de agregado.ipynb
# c:\datasets\databricks\datos\notebooks\Ejemplo 3. Streaming.ipynb
# c:\datasets\databricks\datos\notebooks\Practica 1. Crear tabla empresas.ipynb
# c:\datasets\databricks\datos\notebooks\Practica 2. Crear tabla housing.ipynb
# c:\datasets\databricks\datos\notebooks\Practica 3. Crear funciones de agregados de la tabla housing.ipynb
# c:\datasets\databricks\datos\notebooks\Practica 4. Consultas del dataset taxi_flota_diario.ipynb
# c:\datasets\databricks\datos\notebooks\Practica 5. Streaming de housing.ipynb
# c:\datasets\databricks\datos\presentaciones\00. Que es Databricks.pdf
# c:\datasets\databricks\datos\presentaciones\01. Introduccion Apache Spark.pdf
# c:\datasets\databricks\datos\presentaciones\02. Aplicaciones Continuas.pdf
# c:\datasets\databricks\datos\streaming\file1.csv
# c:\datasets\databricks\datos\streaming\file2.csv
# c:\datasets\databricks\datos\streaming\file3.csv
# c:\datasets\databricks\datos\streaming\file4.csv
# c:\datasets\databricks\datos\streaming\file5.csv
# c:\datasets\databricks\datos\streaming\housing0.csv
# c:\datasets\databricks\datos\streaming\housing1.csv
# c:\datasets\databricks\datos\streaming\housing2.csv
# c:\datasets\databricks\datos\streaming\housing3.csv
# c:\datasets\databricks\datos\streaming\housing4.csv
# c:\datasets\databricks\notebooks\Ejemplo 1. Leer fichero y crear tablas y archivos.ipynb
# c:\datasets\databricks\notebooks\Ejemplo 2. Cambiar nombres de columna y funciones de agregado.ipynb
# c:\datasets\databricks\notebooks\Ejemplo 3. Streaming.ipynb
# c:\datasets\databricks\notebooks\Practica 1. Crear tabla empresas.ipynb
# c:\datasets\databricks\notebooks\Practica 2. Crear tabla housing.ipynb
# c:\datasets\databricks\notebooks\Practica 3. Crear funciones de agregados de la tabla housing.ipynb
# c:\datasets\databricks\notebooks\Practica 4. Consultas del dataset taxi_flota_diario.ipynb
# c:\datasets\databricks\notebooks\Practica 5. Streaming de housing.ipynb
# c:\datasets\databricks\streaming\file1.csv
# c:\datasets\databricks\streaming\file2.csv
# c:\datasets\databricks\streaming\file3.csv
# c:\datasets\databricks\streaming\file4.csv
# c:\datasets\databricks\streaming\file5.csv
# c:\datasets\databricks\streaming\housing0.csv
# c:\datasets\databricks\streaming\housing1.csv
# c:\datasets\databricks\streaming\housing2.csv
# c:\datasets\databricks\streaming\housing3.csv
# c:\datasets\databricks\streaming\housing4.csv
# c:\datasets\datos\apellidos.data
# c:\datasets\datos\ccaa.data
# c:\datasets\datos\nombres.data
# c:\datasets\datos\poblaciones.data
# c:\datasets\datos\provincias.data
# c:\datasets\datos\modificar\fichero.log
# c:\datasets\datos\tool4mob\actividades.data
# c:\datasets\datos\tool4mob\actividades.data.t4m
# c:\datasets\datos\tool4mob\cp.data
# c:\datasets\datos\tool4mob\cp.data.t4m
# c:\datasets\datos\tool4mob\database.sql
# c:\datasets\datos\tool4mob\database.sql.t4m
# c:\datasets\datos\tool4mob\drops.sql
# c:\datasets\datos\tool4mob\drops.sql.t4m
# c:\datasets\datos\tool4mob\entidades.data
# c:\datasets\datos\tool4mob\entidades.data.t4m
# c:\datasets\datos\tool4mob\funciones_1.sql
# c:\datasets\datos\tool4mob\funciones_1.sql.t4m
# c:\datasets\datos\tool4mob\funciones_2.sql
# c:\datasets\datos\tool4mob\funciones_2.sql.t4m
# c:\datasets\datos\tool4mob\idiomas.data
# c:\datasets\datos\tool4mob\idiomas.data.t4m
# c:\datasets\datos\tool4mob\paises.data
# c:\datasets\datos\tool4mob\paises.data.t4m
# c:\datasets\datos\tool4mob\poblaciones.data
# c:\datasets\datos\tool4mob\poblaciones.data.t4m
# c:\datasets\datos\tool4mob\procedures.sql
# c:\datasets\datos\tool4mob\procedures.sql.t4m
# c:\datasets\datos\tool4mob\provincias.data
# c:\datasets\datos\tool4mob\provincias.data.t4m
# c:\datasets\datos\tool4mob\tool4mob.sql
# c:\datasets\datos_v2.1\tool4mob\actividades.data
# c:\datasets\datos_v2.1\tool4mob\cp.data
# c:\datasets\datos_v2.1\tool4mob\database.sql
# c:\datasets\datos_v2.1\tool4mob\drops.sql
# c:\datasets\datos_v2.1\tool4mob\entidades.data
# c:\datasets\datos_v2.1\tool4mob\funciones.sql
# c:\datasets\datos_v2.1\tool4mob\idiomas.data
# c:\datasets\datos_v2.1\tool4mob\paises.data
# c:\datasets\datos_v2.1\tool4mob\poblaciones.data
# c:\datasets\datos_v2.1\tool4mob\procedures.sql
# c:\datasets\datos_v2.1\tool4mob\provincias.data
# c:\datasets\datos_v2.1\tool4mob\tool4mob.sql
# c:\datasets\dni\~$13_Listado_alfabetico_General_Campa_Renta.docx
# c:\datasets\dni\~$exo_ll.docx
# c:\datasets\dni\~$mitidosDefinitivaAlfa LEON - 2.docx
# c:\datasets\dni\~$mitidosDefinitivaAlfa LEON.docx
# c:\datasets\dni\~$mitidosExcluidosDef (3).docx
# c:\datasets\dni\~$mitidosExcluidosDef (4).docx
# c:\datasets\dni\~$titled.FR12.docx
# c:\datasets\dni\data\dni.file
# c:\datasets\dni\data\csv\dni_tipo_00.file
# c:\datasets\dni\data\csv\dni_tipo_01.file
# c:\datasets\dni\data\csv\dni_tipo_02.file
# c:\datasets\dni\data\csv\dni_tipo_03.file
# c:\datasets\dni\data\csv\dni_tipo_04.file
# c:\datasets\dni\dni\censo 24-02-2013-1.pdf
# c:\datasets\dni\dni\Censo Comuneiros 2016.xls
# c:\datasets\dni\dni\comuneros.mdb
# c:\datasets\dni\dni\deiturak.pdf
# c:\datasets\dni\dni\dnis5.xlsx
# c:\datasets\dni\dni\dnis6.xlsx
# c:\datasets\dni\dni\femenino-vasco.pdf
# c:\datasets\dni\dni\masculino-vasco.pdf
# c:\datasets\dni\dni\NombresPersonales.xlsx
# c:\datasets\dni\dni\novocensocomuneiros.xlsx
# c:\datasets\dni\dni\selectividad2016.xlsx
# c:\datasets\dni\dni\~$13_Listado_alfabetico_General_Campa_Renta.docx
# c:\datasets\dni\dni\~$exo_ll.docx
# c:\datasets\dni\dni\~$mitidosDefinitivaAlfa LEON - 2.docx
# c:\datasets\dni\dni\~$mitidosDefinitivaAlfa LEON.docx
# c:\datasets\dni\dni\~$mitidosExcluidosDef (3).docx
# c:\datasets\dni\dni\~$mitidosExcluidosDef (4).docx
# c:\datasets\dni\dni\~$titled.FR12.docx
# c:\datasets\dni\dni\db\data-anterior.csv
# c:\datasets\dni\dni\db\data-old.csv
# c:\datasets\dni\dni\db\data.csv
# c:\datasets\dni\dni\db\database.csv
# c:\datasets\dni\dni\db\excel (está listo y repasado)-22-02-2016.rar
# c:\datasets\dni\dni\db\~$probas.xlsx
# c:\datasets\dni\dni\db\actual-csv\Tipo-01.csv
# c:\datasets\dni\dni\db\actual-csv\Tipo-02.csv
# c:\datasets\dni\dni\db\actual-csv\Tipo-03.csv
# c:\datasets\dni\dni\db\actual-csv\Tipo-04.csv
# c:\datasets\dni\dni\db\actual-csv\Tipo-05.csv
# c:\datasets\dni\dni\db\actual-csv\Tipo-A0.csv
# c:\datasets\dni\dni\db\actual-csv\Tipo-A1.csv
# c:\datasets\dni\dni\db\actual-csv\Tipo-A2.csv
# c:\datasets\dni\dni\db\actual-csv\Tipo-A3.csv
# c:\datasets\dni\dni\db\actual-csv\Tipo-A4.csv
# c:\datasets\dni\dni\db\actual-csv\Tipo-A5.csv
# c:\datasets\dni\dni\db\actual-csv\Tipo-A6.csv
# c:\datasets\dni\dni\db\actual-csv\Tipo-A7.csv
# c:\datasets\dni\dni\db\actual-csv\Tipo-A8.csv
# c:\datasets\dni\dni\db\antiguo\bueu.xlsx
# c:\datasets\dni\dni\db\antiguo\dni-e.txt
# c:\datasets\dni\dni\db\antiguo\dni-n.txt
# c:\datasets\dni\dni\db\antiguo\dni-x.txt
# c:\datasets\dni\dni\db\antiguo\dni.mdb
# c:\datasets\dni\dni\db\antiguo\dni.xlsx
# c:\datasets\dni\dni\db\antiguo\dni0.xlsx
# c:\datasets\dni\dni\db\antiguo\dni01.xlsx
# c:\datasets\dni\dni\db\antiguo\dni2.xlsx
# c:\datasets\dni\dni\db\antiguo\dni3.xlsx
# c:\datasets\dni\dni\db\antiguo\dni4.xlsx
# c:\datasets\dni\dni\db\antiguo\dni5.xlsx
# c:\datasets\dni\dni\db\antiguo\Nombres propios.xlsx
# c:\datasets\dni\dni\db\antiguo\probas.xlsx
# c:\datasets\dni\dni\db\csv\dni-12.csv
# c:\datasets\dni\dni\db\csv\dni-15.csv
# c:\datasets\dni\dni\db\excel\dni-10-L.xlsx
# c:\datasets\dni\dni\db\excel\dni-11-L.xlsx
# c:\datasets\dni\dni\db\excel\dni-12-2.xlsx
# c:\datasets\dni\dni\db\excel\dni-12.xlsx
# c:\datasets\dni\dni\db\excel\dni-13-L.xlsx
# c:\datasets\dni\dni\db\excel\dni-14-L.xlsx
# c:\datasets\dni\dni\db\excel\dni-15.xlsx
# c:\datasets\dni\dni\db\excel\dni-16-L.xlsx
# c:\datasets\dni\dni\db\excel\dni-17-L.xlsx
# c:\datasets\dni\dni\db\excel\dni-18-L.xlsx
# c:\datasets\dni\dni\db\excel\dni-19-L.xlsx
# c:\datasets\dni\dni\db\excel\dni.xlsx
# c:\datasets\dni\dni-validos\dni_mili.xlsx
# c:\datasets\dni\dni-validos\dni_tipo_01.xlsx
# c:\datasets\dni\dni-validos\dni_tipo_02.xlsx
# c:\datasets\dni\dni-validos\dni_tipo_03.xlsx
# c:\datasets\dni\dni-validos\dni_tipo_04.xlsx
# c:\datasets\dni\dni-validos\dni_tipo_05.xlsx
# c:\datasets\dni\dni-validos\dni_tipo_0X.xlsx
# c:\datasets\excel\excel1.xlsx
# c:\datasets\general\apellidos.data
# c:\datasets\general\ccaa.data
# c:\datasets\general\cnaes.data
# c:\datasets\general\direcciones.data
# c:\datasets\general\juridicas.data
# c:\datasets\general\municipios.data
# c:\datasets\general\nombres.data
# c:\datasets\general\profesiones.data
# c:\datasets\general\provincias.data
# c:\datasets\general\sic.data
# c:\datasets\general\stopwords_en.data
# c:\datasets\general\stopwords_es.data
# c:\datasets\imagenes\hombres.zip
# c:\datasets\imagenes\mujeres.zip
# c:\datasets\libros\accesos.data
# c:\datasets\libros\apellidos.data
# c:\datasets\libros\bigdata.data
# c:\datasets\libros\categorias.data
# c:\datasets\libros\ccaa.data
# c:\datasets\libros\cnaes.data
# c:\datasets\libros\compras.data
# c:\datasets\libros\descrip.data
# c:\datasets\libros\devoluciones.data
# c:\datasets\libros\direcciones.data
# c:\datasets\libros\editoriales.data
# c:\datasets\libros\empresas.data
# c:\datasets\libros\grupos.data
# c:\datasets\libros\juridicas.data
# c:\datasets\libros\libros.data
# c:\datasets\libros\municipios.data
# c:\datasets\libros\nombres.data
# c:\datasets\libros\pedidos.data
# c:\datasets\libros\profesiones.data
# c:\datasets\libros\provincias.data
# c:\datasets\libros\reservas.data
# c:\datasets\libros\stopwords_en.data
# c:\datasets\libros\stopwords_es.data
# c:\datasets\libros\sugerencias.data
# c:\datasets\libros\usuarios.data
# c:\datasets\mail\key.key
# c:\datasets\malware\malware.key
# c:\datasets\seguridad\tool4mob\acceso.data
# c:\datasets\seguridad\tool4mob\accion_clave_proyecto.data
# c:\datasets\seguridad\tool4mob\actividad_miembro.data
# c:\datasets\seguridad\tool4mob\administracion.data
# c:\datasets\seguridad\tool4mob\alojamiento.data
# c:\datasets\seguridad\tool4mob\altas_miembro.data
# c:\datasets\seguridad\tool4mob\apoyo_concepto.data
# c:\datasets\seguridad\tool4mob\area_participante.data
# c:\datasets\seguridad\tool4mob\calidad_miembro.data
# c:\datasets\seguridad\tool4mob\codigo_postal.data
# c:\datasets\seguridad\tool4mob\convenio_miembro.data
# c:\datasets\seguridad\tool4mob\copia_seguridad.data
# c:\datasets\seguridad\tool4mob\coste_concepto.data
# c:\datasets\seguridad\tool4mob\entidad_bancaria.data
# c:\datasets\seguridad\tool4mob\erntidad_proyecto.data
# c:\datasets\seguridad\tool4mob\historial_academico.data
# c:\datasets\seguridad\tool4mob\historial_administraciones.data
# c:\datasets\seguridad\tool4mob\historial_alojamientos.data
# c:\datasets\seguridad\tool4mob\historial_intermediarios.data
# c:\datasets\seguridad\tool4mob\historial_miembros.data
# c:\datasets\seguridad\tool4mob\historial_participantes.data
# c:\datasets\seguridad\tool4mob\historial_proyectos.data
# c:\datasets\seguridad\tool4mob\historial_socios.data
# c:\datasets\seguridad\tool4mob\idioma.data
# c:\datasets\seguridad\tool4mob\idiomas_participante.data
# c:\datasets\seguridad\tool4mob\ingresos_proyecto.data
# c:\datasets\seguridad\tool4mob\ingreso_concepto.data
# c:\datasets\seguridad\tool4mob\intermediario.data
# c:\datasets\seguridad\tool4mob\linguistica_concepto.data
# c:\datasets\seguridad\tool4mob\miembro.data
# c:\datasets\seguridad\tool4mob\movilidad.data
# c:\datasets\seguridad\tool4mob\nivel_educativo.data
# c:\datasets\seguridad\tool4mob\nivel_movilidad.data
# c:\datasets\seguridad\tool4mob\pagos_apoyo_organizativo.data
# c:\datasets\seguridad\tool4mob\pagos_costes_curso.data
# c:\datasets\seguridad\tool4mob\pagos_linguistica.data
# c:\datasets\seguridad\tool4mob\pagos_participante.data
# c:\datasets\seguridad\tool4mob\pais.data
# c:\datasets\seguridad\tool4mob\paises_intermediario.data
# c:\datasets\seguridad\tool4mob\participante.data
# c:\datasets\seguridad\tool4mob\participante_concepto.data
# c:\datasets\seguridad\tool4mob\poblacion.data
# c:\datasets\seguridad\tool4mob\provincia.data
# c:\datasets\seguridad\tool4mob\proyecto.data
# c:\datasets\seguridad\tool4mob\sector_movilidad.data
# c:\datasets\seguridad\tool4mob\sector_socio.data
# c:\datasets\seguridad\tool4mob\socio.data
# c:\datasets\seguridad\tool4mob\tipo_actividad.data
# c:\datasets\seguridad\tool4mob\tipo_actividad_ingles.data
# c:\datasets\seguridad\tool4mob\tipo_alojamiento.data
# c:\datasets\seguridad\tool4mob\tipo_participante.data
# c:\datasets\seguridad\tool4mob\tipo_proyecto.data
# c:\datasets\seguridad\tool4mob\tool4Mob.data
# c:\datasets\seguridad\tool4mob\usuario.data
# c:\datasets\sites\perfumes24h.com\data\audios.data
# c:\datasets\sites\perfumes24h.com\data\images.data
# c:\datasets\sites\perfumes24h.com\data\javascripts.data
# c:\datasets\sites\perfumes24h.com\data\links.data
# c:\datasets\sites\perfumes24h.com\data\stylesheets.data
# c:\datasets\sites\perfumes24h.com\data\urls.data
# c:\datasets\sites\perfumes24h.com\data\videos.data
# c:\datasets\tool4mob\paises_ingles.data
# c:\datasets\tool4mob\paises_ingles_2.data
# c:\datasets\tool4mob\data\acciones_proyectos.data
# c:\datasets\tool4mob\data\actividades_miembros.data
# c:\datasets\tool4mob\data\apellidos.data
# c:\datasets\tool4mob\data\areas_estudios.data
# c:\datasets\tool4mob\data\codigos_postales.data
# c:\datasets\tool4mob\data\direcciones.data
# c:\datasets\tool4mob\data\entidades_bancarias.data
# c:\datasets\tool4mob\data\entidades_proyectos.data
# c:\datasets\tool4mob\data\idiomas.data
# c:\datasets\tool4mob\data\niveles_estudios.data
# c:\datasets\tool4mob\data\nombres.data
# c:\datasets\tool4mob\data\paises.data
# c:\datasets\tool4mob\data\paises.xlsx
# c:\datasets\tool4mob\data\paises_ingles.csv
# c:\datasets\tool4mob\data\paises_ingles.xlsx
# c:\datasets\tool4mob\data\poblaciones.data
# c:\datasets\tool4mob\data\provincias.data
# c:\datasets\tool4mob\data\sectores_centros.data
# c:\datasets\tool4mob\data\sectores_movilidades.data
# c:\datasets\tool4mob\data\sectores_socios.data
# c:\datasets\tool4mob\data\tipos_actividades.data
# c:\datasets\tool4mob\data\tipos_alojamientos.data
# c:\datasets\tool4mob\data\tipos_proyectos.data
# c:\datasets\tool4mob\excel\codigos_bic_completo.xlsx
# c:\datasets\tool4mob\excel\codigos_postales_originales.txt
# c:\datasets\tool4mob\excel\cp.xlsx
# c:\datasets\tool4mob\excel\cps.data
# c:\datasets\tool4mob\excel\cps.xlsx
# c:\datasets\tool4mob\excel\cp_nuevos.data
# c:\datasets\tool4mob\excel\entidades_bancarias.xlsx
# c:\datasets\tool4mob\excel\idiomas.xlsx
# c:\datasets\tool4mob\excel\municipios.data
# c:\datasets\tool4mob\excel\municipios.xlsx
# c:\datasets\tool4mob\excel\municipios_2023.xlsx
# c:\datasets\tool4mob\excel\munis.data
# c:\datasets\tool4mob\excel\_CodigosPostales_original.xlsx
# c:\datasets\tool4mob\excel\_municipios.xlsx
# c:\datasets\tool4mob\fondos\base\foto
# c:\datasets\tool4mob\fondos\base\logo
# c:\datasets\tool4mob\fondos\forms\tool4mov_001.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_002.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_003.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_004.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_005.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_006.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_007.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_008.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_009.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_010.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_011.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_012.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_013.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_014.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_015.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_016.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_017.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_018.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_019.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_020.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_021.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_022.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_023.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_024.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_025.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_026.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_027.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_028.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_029.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_030.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_031.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_032.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_033.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_034.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_035.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_036.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_037.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_038.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_039.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_040.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_041.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_042.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_043.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_044.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_045.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_046.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_047.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_048.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_049.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_050.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_051.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_052.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_053.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_054.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_055.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_056.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_057.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_058.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_059.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_060.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_061.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_062.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_063.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_064.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_065.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_066.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_067.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_068.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_069.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_070.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_071.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_072.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_073.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_074.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_075.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_076.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_077.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_078.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_079.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_080.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_081.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_082.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_083.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_084.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_085.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov_086.jpg
# c:\datasets\tool4mob\fondos\forms\tool4mov
jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_160.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_161.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_162.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_163.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_164.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_165.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_166.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_167.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_168.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_169.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_170.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_171.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_172.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_173.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_174.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_175.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_176.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_177.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_178.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_179.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_180.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_181.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_182.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_183.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_184.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_185.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_186.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_187.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_188.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_189.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_190.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_191.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_192.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_193.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_194.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_195.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_196.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_197.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_198.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_199.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_200.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_201.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_202.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_203.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_204.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_205.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_206.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_207.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_208.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_209.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_210.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_211.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_212.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_213.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_214.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_215.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_216.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_217.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_218.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_219.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_220.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_221.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_222.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_223.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_224.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_225.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_226.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_227.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_228.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_229.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_230.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_231.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_232.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_233.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_234.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_235.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_236.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_237.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_238.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_239.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_240.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_241.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_242.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_243.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_244.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_245.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_246.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_247.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_248.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_249.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_250.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_251.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_252.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_253.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_254.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_255.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_256.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_257.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_258.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_259.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_260.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_261.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_262.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_263.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_264.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_265.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_266.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_267.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_268.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_269.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_270.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_271.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_272.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_273.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_274.jpg
# c:\datasets\tool4mob_v2.1\images\forms\tool4mov_275.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_001.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_002.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_003.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_004.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_005.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_006.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_007.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_008.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_009.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_010.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_011.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_012.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_013.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_014.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_015.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_016.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_017.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_018.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_019.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_020.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_021.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_022.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_023.jpg
# c:\datasets\tool4mob_v2.1\images\login\fondo_024.jpg
# c:\datasets\tool4mob_v2.1\seguridad\tool4mob_2023.12.20_085956.t4m
# c:\datasets\tool4mob_v2.1\seguridad\database\tool4mob.tool4mob
# c:\datasets\tool4mob_v2.1\sql\funciones.sql
# c:\datasets\tool4mob_v2.1\sql\tool4mob.sql
# c:\datasets\tool4mob_v2.1\sql\tool4mob_0_old.sql
# c:\datasets\tool4mob_v2.1\sql\tool4mob_1_2023_01_02.sql
# c:\datasets\tool4mob_v2.1\sql\tool4mob_2_2023_01_04.sql
# c:\datasets\tool4mob_v2.1\temp\133445249315463027.docx
# c:\datasets\tool4mob_v2.1\templates\template_administracion.docx
# c:\datasets\tool4mob_v2.1\templates\template_alojamiento.docx
# c:\datasets\tool4mob_v2.1\templates\template_intermediario.docx
# c:\datasets\tool4mob_v2.1\templates\template_miembro.docx
# c:\datasets\tool4mob_v2.1\templates\template_movilidad.docx
# c:\datasets\tool4mob_v2.1\templates\template_participante.docx
# c:\datasets\tool4mob_v2.1\templates\template_proyecto.docx
# c:\datasets\tool4mob_v2.1\templates\template_socio.docx
# c:\datasets\tool4mob_v2.1\templates\~$antilla_alojamiento.docx
# c:\datasets\tool4mob_v2.1\templates\~$mplate_organizacion.docx
# c:\datasets\tool4mob_v2.1\templates\~$mplate_participante.docx
# c:\datasets\tool4mov_database_v2.1\acciones_proyectos.csv
# c:\datasets\tool4mov_database_v2.1\apoyos_conceptos.csv
# c:\datasets\tool4mov_database_v2.1\areas_estudios.csv
# c:\datasets\tool4mov_database_v2.1\entidades_proyectos.csv
# c:\datasets\tool4mov_database_v2.1\historial_academicos.csv
# c:\datasets\tool4mov_database_v2.1\ingles_actividades.csv
# c:\datasets\tool4mov_database_v2.1\ingresos_conceptos.csv
# c:\datasets\tool4mov_database_v2.1\ingresos_proyectos.csv
# c:\datasets\tool4mov_database_v2.1\intermediarios.csv
# c:\datasets\tool4mov_database_v2.1\movilidades.csv
# c:\datasets\tool4mov_database_v2.1\niveles_estudios.csv
# c:\datasets\tool4mov_database_v2.1\pagos_apoyos.csv
# c:\datasets\tool4mov_database_v2.1\pagos_participantes.csv
# c:\datasets\tool4mov_database_v2.1\paises_intermediarios.csv
# c:\datasets\tool4mov_database_v2.1\participantes.csv
# c:\datasets\tool4mov_database_v2.1\participantes_conceptos.csv
# c:\datasets\tool4mov_database_v2.1\proyectos.csv
# c:\datasets\tool4mov_database_v2.1\sectores_centros.csv
# c:\datasets\tool4mov_database_v2.1\sectores_movilidades.csv
# c:\datasets\tool4mov_database_v2.1\sectores_socios.csv
# c:\datasets\tool4mov_database_v2.1\socios.csv
# c:\datasets\tool4mov_database_v2.1\tipos_actividades.csv
# c:\datasets\tool4mov_database_v2.1\tipos_alojamientos.csv
# c:\datasets\tool4mov_database_v2.1\tipos_proyectos.csv

# %% [markdown]
# La función os.path.**join**, devuelve la unión entre el nombre del directorio del archivo y el nombre del archivo.
#
# El siguiente ejemplo muestra el nombre completo del archivo (nombre de directorio y nombre del archivo).

# %%
directorio = 'c:\\datasets'
try:
    for fichero in os.listdir(directorio):
        nombre_fichero = os.path.join(directorio, fichero)
        print(nombre_fichero)
except FileNotFoundError as fnfe:
    print('El directorio no existe')
# Out:
# c:\datasets\csv
# c:\datasets\data
# c:\datasets\databricks
# c:\datasets\datos
# c:\datasets\datos_v2.1
# c:\datasets\dni
# c:\datasets\excel
# c:\datasets\general
# c:\datasets\imagenes
# c:\datasets\libros
# c:\datasets\mail
# c:\datasets\malware
# c:\datasets\seguridad
# c:\datasets\sites
# c:\datasets\tool4mob
# c:\datasets\tool4mob_v2.1
# c:\datasets\tool4mov_database_v2.1

# %% [markdown]
# La función os.**remove**, elimina un archivo.
#
# El siguiente ejemplo elimina los archivos de un directorio.

# %%
directorio = 'c:\\temp'
for file in os.listdir(directorio):
    os.remove(os.path.join(directorio, file))

# %% [markdown]
# La función os.path.**dirname**, devuelve la ruta completa del directorio al cual pertenece el archivo.

# %%
file = 'c:\\datasets\\probas\\probas.data'
os.path.dirname(file)
# Out:
# 'c:\\datasets\\probas'

# %% [markdown]
# La función os.path.**basename**, devuelve el nombre del archivo.

# %%
file = 'c:\\datasets\\probas\\probas.data'
os.path.basename(file)
# Out:
# 'probas.data'

# %% [markdown]
# La función os.path.**abspath**, devuelve el nombre completo del archico formado por el nombre del directorio y el nombre del archivo.

# %%
file = 'c:\\datasets\\data\\ccaa.data'
os.path.abspath(file)

# %% [markdown]
# La función os.path.**split**, devuelve una tupla formada por el nombre del directorio y el nombre del archivo respectivamente.

# %%
file = 'c:\\datasets\\probas\\probas.data'
path, namefile = os.path.split(file)
print(path)
print(namefile)
# Out:
# c:\datasets\probas
# probas.data

# %% [markdown]
# La función os.path.**isfile**, devuelve verdadero si es un archivo.

# %%
file = 'c:\\datasets\\data\\ccaa.data'
if os.path.isfile(file):
    print('Es un archivo')
# Out:
# Es un archivo

# %% [markdown]
# La función os.path.**isdir**, devuelve verdadero si es un directorio.

# %%
dir = 'c:\\datasets\\data'
if os.path.isdir(dir):
    print('Es un directorio')
# Out:
# Es un directorio

# %% [markdown]
# La función os.path.**islink**, devuelve verdadero si es un acceso directo o enlace simbólico.

# %%
dir = 'c:\\datasets\\data'
if os.path.islink(dir):
    print('Es un acceso directo')

# %% [markdown]
# La función os.path.**exists**, devuelve verdadero si un archivo o directorio existe.

# %%
dir = 'c:\\datasets\\data'
if os.path.exists(dir):
    print('El directorio ya existe')
# Out:
# El directorio ya existe

# %% [markdown]
# La función os.path.**getsize**, devuelve el tamaño en bytes de un archivo.

# %%
file = 'c:\\datasets\\data\\ccaa.data'
bytes = os.path.getsize(file)
print(f'{file} ocupa {bytes} bytes')
# Out:
# c:\datasets\data\ccaa.data ocupa 668 bytes

# %% [markdown]
# Importamos el módulo **datetime** de Python, para trabajar con fechas

# %%
import datetime as dt

# %% [markdown]
# La función os.path.**getctime**, devuelve la fecha y hora en que se creó el archivo o directorio expresado en segundos.

# %%
file = 'c:\\datasets\\data\\ccaa.data'
segundos = os.path.getctime(file)
fecha = dt.datetime.fromtimestamp(segundos)
print(fecha)
# Out:
# 2023-06-24 22:00:17.558382

# %% [markdown]
# La función os.path.**getatime**, devuelve la fecha y hora a la que se accedió por última vez al archivo o directorio expresado en segundos.

# %%
file = 'c:\\datasets\\data\\ccaa.data'
segundos = os.path.getatime(file)
fecha = dt.datetime.fromtimestamp(segundos)
print(fecha)
# Out:
# 2024-04-18 17:29:21.961353

# %% [markdown]
# La función os.path.**getmtime**, devuelve la fecha y hora en que se modificó por última vez el archivo o directorio.

# %%
file = 'c:\\datasets\\data\\ccaa.data'
segundos = os.path.getmtime(file)
fecha = dt.datetime.fromtimestamp(segundos)
print(fecha)
# Out:
# 2022-04-16 02:32:22

# %% [markdown]
# La función os.**stat**, devuelve información sobre el archivo o directorio.

# %%
file = 'c:\\datasets\\data\\ccaa.data'
state = os.stat(file)
state
# Out:
# os.stat_result(st_mode=33206, st_ino=18014398510751100, st_dev=4345457957885620246, st_nlink=1, st_uid=0, st_gid=0, st_size=668, st_atime=1713454161, st_mtime=1650069142, st_ctime=1687636817)

# %%
path, name = os.path.split(file)
namefile = os.path.abspath(file)
size = state.st_size
date_access = dt.datetime.fromtimestamp(state.st_atime)
date_last = dt.datetime.fromtimestamp(state.st_mtime)
date_create = dt.datetime.fromtimestamp(state.st_ctime)
print(f'File => {namefile}')
print(f'Path => {path}')
print(f'Name => {name}')
print(f'Size => {size}')
print(f'date access => {date_access}')
print(f'date last => {date_last}')
print(f'date create => {date_create}')
# Out:
# File => c:\datasets\data\ccaa.data
# Path => c:\datasets\data
# Name => ccaa.data
# Size => 668
# date access => 2024-04-18 17:29:21.961353
# date last => 2022-04-16 02:32:22
# date create => 2023-06-24 22:00:17.558382
